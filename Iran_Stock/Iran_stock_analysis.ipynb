# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

# %%
data=pd.read_csv('Stock_analysis.csv')
pd.options.display.max_columns = None
display(data)
# Out:
#          Date  Famelli  Foolad   Zob  Fakhooz  Kaveh   Dey  Vabemellat  \
# 0   3/10/2020     4.98    4.97  4.98     4.39   4.99  0.07        4.83
# 1   4/10/2020    -4.93   -3.31  3.17    -5.00  -4.96 -5.00       -3.39
# 2   5/10/2020    -4.54   -2.80  2.10    -4.99  -4.58  5.00       -1.27
# 3   6/10/2020     1.99    2.13  4.99     3.52   4.98  5.00        4.87
# 4   7/10/2020     0.88    1.12  4.99    -0.03   2.05  5.00        4.83
# 5  10/10/2020    -2.97   -2.78  4.97    -4.91  -4.97  5.00        0.00
#
#    Vabesader  Vatejarat  Vapars  Kama  Kagal  Kachad  Vamaaden  Koravi  \
# 0       4.96       4.78    4.96     5   4.97    1.43      3.03    4.98
# 1      -2.84       4.93    5.00     5  -4.93   -4.97     -4.97   -5.00
# 2      -3.07       4.71    4.76     5  -0.09    0.00     -4.99   -4.98
# 3       4.20       4.89    4.83     5   3.43    2.73     -1.37    5.00
# 4       4.78       4.98    4.85     5   0.00   -1.15      0.00    4.99
# ...

# %%
Famelli=data['Famelli']
Foolad=data['Foolad']
Zob=data['Zob']
Fakhooz=data['Fakhooz']
Kaveh=data['Kaveh']

Dey=data['Dey']
Vabemellat=data['Vabemellat']
Vabesader=data['Vabesader']
Vatejarat=data['Vatejarat']
Vapars=data['Vapars']

Kama=data['Kama']
Kagal=data['Kagal']
Kachad=data['Kachad']
Vamaaden=data['Vamaaden']
Koravi=data['Koravi']

Hakeshti=data['Hakeshti']
Toril=data['Toril']
Haril=data['Haril']
Hafares=data['Hafares']
Hatayed=data['Hatayed']
Hasina=data['Hasina']

Thashahed=data['Thashahed']
Kerman=data['Kerman']
Sakht=data['Sakht']
Vasakht=data['Vasakht']
Vatoos=data['Vatoos']
Saomra=data['Saomra']

Famelli_sum=0
Foolad_sum=0
Zob_sum=0
Fakhooz_sum=0
Kaveh_sum=0

Dey_sum=0
Vabemellat_sum=0
Vabesader_sum=0
Vatejarat_sum=0
Vapars_sum=0

Kama_sum=0
Kagal_sum=0
Kachad_sum=0
Vamaaden_sum=0
Koravi_sum=0

Hakeshti_sum=0
Toril_sum=0
Haril_sum=0
Hafares_sum=0
Hatayed_sum=0
Hasina_sum=0

Thashahed_sum=0
Kerman_sum=0
Sakht_sum=0
Vasakht_sum=0
Vatoos_sum=0
Saomra_sum=0

for i in Famelli:
    Famelli_sum=Famelli_sum+i
print(Famelli_sum)

for i in Foolad:
    Foolad_sum=Foolad_sum+i
print(Foolad_sum)

for i in Zob:
    Zob_sum=Zob_sum+i
print(Zob_sum)

for i in Fakhooz:
    Fakhooz_sum=Fakhooz_sum+i
print(Fakhooz_sum)

for i in Kaveh:
    Kaveh_sum=Kaveh_sum+i
print(Kaveh_sum)

print(' ')
print(' ')


for i in Dey:
    Dey_sum=Dey_sum+i
print(Dey_sum)

for i in Vabemellat:
    Vabemellat_sum=Vabemellat_sum+i
print(Vabemellat_sum)

for i in Vabesader:
    Vabesader_sum=Vabesader_sum+i
print(Vabesader_sum)

for i in Vatejarat:
    Vatejarat_sum=Vatejarat_sum+i
print(Vatejarat_sum)

for i in Vapars:
    Vapars_sum=Vapars_sum+i
print(Vapars_sum)

print(' ')
print(' ')

for i in Kama:
    Kama_sum=Kama_sum+i
print(Kama_sum)

for i in Kagal:
    Kagal_sum=Kagal_sum+i
print(Kagal_sum)

for i in Kachad:
    Kachad_sum=Kachad_sum+i
print(Kachad_sum)

for i in Vamaaden:
    Vamaaden_sum=Vamaaden_sum+i
print(Vamaaden_sum)

for i in Koravi:
    Koravi_sum=Koravi_sum+i
print(Koravi_sum)

print(' ')
print(' ')

for i in Hakeshti:
    Hakeshti_sum=Hakeshti_sum+i
print(Hakeshti_sum)

for i in Toril:
    Toril_sum=Toril_sum+i
print(Toril_sum)

for i in Haril:
    Haril_sum=Haril_sum+i
print(Haril_sum)

for i in Hafares:
    Hafares_sum=Hafares_sum+i
print(Hafares_sum)

for i in Hatayed:
    Hatayed_sum=Hatayed_sum+i
print(Hatayed_sum)

for i in Hasina:
    Hasina_sum=Hasina_sum+i
print(Hasina_sum)

print(' ')
print(' ')


for i in Thashahed:
    Thashahed_sum=Thashahed_sum+i
print(Thashahed_sum)

for i in Kerman:
    Kerman_sum=Kerman_sum+i
print(Kerman_sum)

for i in Sakht:
    Sakht_sum=Sakht_sum+i
print(Sakht_sum)

for i in Vasakht:
    Vasakht_sum=Vasakht_sum+i
print(Vasakht_sum)

for i in Vatoos:
    Vatoos_sum=Vatoos_sum+i
print(Vatoos_sum)

for i in Saomra:
    Saomra_sum=Saomra_sum+i
print(Saomra_sum)
# Out:
# -4.59
# -0.6699999999999999
# 25.2
# -7.0200000000000005
# -2.4899999999999993
#
#
# 15.07
# 9.870000000000001
# 12.900000000000002
# 29.090000000000003
# 29.259999999999998
#
#
# 25
# 3.43
# -2.01
# -8.3
# 9.97
#
#
# 0
# 30
# 14.46
# -14.29
# -3.400000000000002
# 7.58
#
#
# -29.95
# 20
# 17.88
# 29.070000000000004
# 29.910000000000004
# -30

# %%
Metal_group=['Famelli','Foolad', 'Zob', 'Fakhooz', 'Kaveh']
index = np.arange(len(Metal_group))
Values=[Famelli_sum, Foolad_sum, Zob_sum, Fakhooz_sum, Kaveh_sum]               
plt.bar(Metal_group,Values,color=('gold', 'b', 'g', 'red','yellow'))
plt.xlabel('Stock name')
plt.ylabel('Price variation(%)')
plt.title('The price variation of some stocks in metal group for the period of 03/Oct/2020-10/Oct/2020', size=8)
plt.ylim(-15,35)
plt.savefig('Metal_group.pdf')

# %%
Bank_group=['Dey','Vabemellat', 'Vabesader', 'Vatejart', 'Vapars']
Values=[Dey_sum, Vabemellat_sum, Vabesader_sum, Vatejarat_sum, Vapars_sum]               
plt.bar(Bank_group,Values,color=('blue', 'blue', 'blue', 'green','green'))
plt.xlabel('Stock name')
plt.ylabel('Price variation(%)')
plt.title('The price variation of some stocks in bank group for the period of 03/Oct/2020-10/Oct/2020', size=8)
plt.ylim(0,35)
plt.savefig('Bank_group.pdf')

# %%
Mine_group=['Kama','Kagal', 'Kachd', 'Vamaaden', 'Koravi']
Values=[Kama_sum, Kagal_sum, Kachad_sum, Vamaaden_sum, Koravi_sum]               
plt.bar(Mine_group,Values,color=('green', 'yellow', 'yellow', 'red','blue'))
plt.xlabel('Stock name')
plt.ylabel('Price variation(%)')
plt.title('The price variation of some stocks in mine group for the period of 03/Oct/2020-10/Oct/2020', size=8)
plt.ylim(-15,30)
plt.savefig('Mine_group.pdf')

# %%
Transportation_group=['Hakeshti','Toril', 'Haril', 'Hafares', 'Hatayed', 'Hasina']
Values=[Hakeshti_sum, Toril_sum, Haril_sum, Hafares_sum, Hatayed_sum, Hasina_sum]               
plt.bar(Transportation_group,Values,color=('green', 'green', 'green', 'red','red', 'blue'))
plt.xlabel('Stock name')
plt.ylabel('Price variation(%)')
plt.title('The price variation of some stocks in transportation group for the period of 03/Oct/2020-10/Oct/2020', size=8)
plt.ylim(-15,35)
plt.savefig('Transportation_group.pdf')

# %%
Transportation_group=['Hakeshti','Toril', 'Haril', 'Hafares', 'Hatayed', 'Hasina']
Values=[Hakeshti_sum, Toril_sum, Haril_sum, Hafares_sum, Hatayed_sum, Hasina_sum]               
plt.bar(Transportation_group,Values,color=('green', 'green', 'green', 'red','red', 'blue'))
plt.xlabel('Stock name')
plt.ylabel('Price variation(%)')
plt.title('The price variation of some stocks in transportation group for the period of 03/Oct/2020-10/Oct/2020', size=8)
plt.ylim(-15,35)
plt.savefig('Transportation_group.pdf')

# %%
Properties_group=['Thashahed','Kerman', 'Sakht', 'Vasakht', 'Vatoos','Saomra']
Values=[Thashahed_sum, Kerman_sum, Sakht_sum, Vasakht_sum, Vatoos_sum, Saomra_sum]               
plt.bar(Properties_group,Values,color=('red', 'green', 'green', 'green','green', 'red'))
plt.xlabel('Stock name')
plt.ylabel('Price variation(%)')
plt.title('The price variation of some stocks in properties group for the period of 03/Oct/2020-10/Oct/2020', size=8)
plt.ylim(-35,35)
plt.savefig('Properties_group.pdf')
